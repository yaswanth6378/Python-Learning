# %%
def main():
    x = int(input("whats x?"))
    print("x square is :",square(x))
def square(n):
    
    return n * n
main()
# Out:
# whats x? 66
# x square is : 4356

# %%
def square(x):
    return pow(x,3)
    
x = int(input("enter a nuber"))
print("the suare is :",square(x))
# Out:
# enter a nuber 2
# the suare is : 8

# %%
def main():
    x = int(input("enter a number:"))
    print("square of x is:",square(x))
def square(x):
    return pow(x,2)
main()
# Out:
# enter a number: 2
# square of x is: 4
