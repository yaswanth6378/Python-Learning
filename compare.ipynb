# %% [markdown]
#  ## using elif

# %%
x = int(input("what is x?:"))
y = int(input("what is y?:"))
if x > y:
    print("xis >")
elif x < y:
    print("y is >")
elif x== y :
    print("equal")
# Out:
# what is x?: 2
# what is y?: 2
# equal

# %% [markdown]
# ## using if

# %%
x = int(input("what is x?:"))
y = int(input("what is y?:"))
if x > y:
    print("xis >")
if x < y:
    print("y is >")
if x== y :
    print("equal")
# Out:
# what is x?: 2
# what is y?: 2
# equal

# %% [markdown]
# ## using else

# %%
x = int(input("what is x?:"))
y = int(input("what is y?:"))
if x > y:
    print("xis >")
elif x < y:
    print("y is >")
else:
    print("equal")
# Out:
# what is x?: 1
# what is y?: 1
# equal

# %% [markdown]
# ## using or

# %%
x = int(input("what is x?:"))
y = int(input("what is y?:"))
if x < y or x > y :
    print("x is not equal to y")
else:
    print("x is eqaul to y")
# Out:
# what is x?: 2
# what is y?: 2
# x is eqaul to y

# %% [markdown]
# ## !=

# %%
x = int(input("what is x?:"))
y = int(input("what is y?:"))
if x != y:
    print("x is not equal to y")
else:
    print("x is eqaul to y")
# Out:
# what is x?: 1
# what is y?: 1
# x is eqaul to y

# %% [markdown]
# ## ==

# %%
x = int(input("what is x?:"))
y = int(input("what is y?:"))
if x == y:
    print("x is equal to y")
else:
    print("x is not eqaul to y")
# Out:
# what is x?: 5
# what is y?: 2
# x is not eqaul to y

# %% [markdown]
# ## lets discuss about "and"

# %% [markdown]
# ##  lets discuss about "and" operator

# %%
score = int(input("score:"))
if score >= 90 and score <=100:
    print("Grade A ")
elif score >= 80 and score < 90:
    print("Grade B")
elif score >= 70 and score < 80:
    print("Grade c")
else:
     print("Grade F")
# Out:
# score: 55
# Grade F

# %%
## lets make the code more easier

# %%
score = int(input("score:"))
if  90 <= score <=100:
    print("Grade A ")
elif 80 <= score < 90:
    print("Grade B")
elif  70 <= score < 80:
    print("Grade c")
else:
     print("Grade F")
# Out:
# score: 85
# Grade B

# %%
## i think still we can make it more easy

# %%
score = int(input("score:"))
if score >= 90:
    print("Grade A ")
elif score >= 80:
    print("Grade B")
elif  score >= 70:
    print("Grade c")
else:
     print("Grade F")
# Out:
# score: 90
# Grade A

# %%
## here a doubt arised for me ,what if i use if instead of elif

# %%
score = int(input("score:"))
if score >= 90:
    print("Grade A ")
if score >= 80:
    print("Grade B")
if  score >= 70:
    print("Grade c")
else:
     print("Grade F")
# Out:
# score: 95
# Grade A
# Grade B
# Grade c

# %%
## here i tougth that it will print A but ther is also B and C beacuase when condition is true it will
## also check other lines but when we elif if conditon is true  the progrsm will end.

# %%
## finding even or odd 
## + - addition
## - - subraction
## * - multiplication
## / - division
## % - reminder - (modulo)

# %% [markdown]
# ## finding a integer even or odd?

# %%
num = int(input("enter a number:"))
if num % 2 == 0:
    print("Even")
else :
    print("odd")
# Out:
# enter a number: 5
# odd

# %% [markdown]
# ## above wee tryed with built function of python , now lets try by creating our own function

# %%
def main():
    x = int(input("whats x?"))
    if is_even(x):
        print("even")
    else:
        print("odd")
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False
main()
# Out:
# whats x? 5
# odd

# %%
def main():
    x = int(input("whats x?"))
    if is_even(x):
        print("even")
    else:
        print("odd")
def is_even(n):
   return n % 2 == 0
main()
# Out:
# whats x? 6
# even

# %%
name = input("enter the name:")
if name == "yash":
    print("plp")
elif name == "prasanna":
    print("plp")
else :
    print("clp")
# Out:
# enter the name: ram
# clp

# %% [markdown]
# ## lets use match builtin function

# %%
name = input("enter the name:")
match name:
    case "yash":
        print("plp")
    case "prasanna":
        print("plp")
    case "ram":
        print("clp")
    case _ :
        print("who ?")
# Out:
# enter the name: reddy
# who ?

# %%
name = input("enter the name:")
match name:
    case "yash" | "prasanna" | "ram":
        print("clp")
    case "tulasi":
        print("plp")
    case _ :
        print("who ?")
# Out:
# enter the name: yash
# clp

# %%
name = input("enter name")
match name:
     case "sai" | "lachi" | "yash" :
         print("stays in 506")
     case "madhav":
         print("stays in 507")
     case _:
         print("who?")
# Out:
# enter name REDDY
# who?
