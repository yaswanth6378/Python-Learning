# %%
def main():
    difficulty = input("Difficult or Casual ?").capitalize()
    players = input("Singleplayer or Multipalyer ?").capitalize()
    if  difficulty == "Difficult":
        if players == "Multiplayer":
            recommend("poker")
        elif players == "Singleplayer":
            recommend("klondike")
        else :
            print(" please enter valid number of players" )
    elif difficulty == "Casual" :
        if players == "Multiplayer":
            recommend("Hearts")
        elif players == "Singlepalyer":
            recommend("clock")
        else :
            print("please enter valid no of players")
    else :
        print("please enter a valid difficulty")
def recommend(game):
    print("you migth like",game)
main()
# Out:
# Difficult or Casual ? difficult

# %%
def main():
    difficulty = input("Difficult or Casual?")
    players = input("Single-player or Multiplayer?")

    if difficulty == "Difficult":
        if players == "Multiplayer":
            recommend("kings")
        elif players == "Single-player" :
            recommend("queen")
        else :
            print("please enter valid no of player")
    elif difficulty == "Casual":
        if players == "Multiplayer":
            recommend("jacks")
        elif players == "Single-player":
            recommend("ace")
            
        else :
                print("please enter valid number players")
    else :
        print("please enter valid difficulty")
def recommend(game):
    print("you migth like",game)

main()
# Out:
# Difficult or Casual? difficult
# Single-player or Multiplayer? Single-player
# please enter valid difficulty

# %%
def main():
    difficulty = input("difficult or casual").capitalize()
    players = input("Single player or multiplayer").capitalize()
    if difficulty == "Difficult" :
        if players == "Multiplayer":
            recommend("pubg")
        elif players == "Single player":
            recommend("chess")
        else :
            print("please enter valid number of players")
    elif difficulty == "Casual":
        if players == "Multiplayer":
            recommend("Free fire")
        elif players == "Single player":
            recommend("candy crush")
        else :
            print("valid number of players")
    else :
        print("please enter a valid difficulty")
def recommend(game):
    print("you migth like ",game)
main()
# Out:
# difficult or casual casual
# Single player or multiplayer single player
# you migth like  candy crush

# %%
def main():
    difficulty = input("enter difficult or casual").capitalize()
    players = input("multiplayer or singleplayer").capitalize()
    match (difficulty,players):
        case ("Difficult","Multiplayer"):
            recommend("pubg")
        case ("Difficult","Singleplayer"):
            recommend("chess")
        case ("Difficult", _):
            print("enter valid number players")
        case ("Casual","Multiplayer"):
            recommend("Free fire")
        case ("Casual","Singleplayer"):
            recommend("candy crush")
        case("Casual",_):
            print("please enter valid number of players")
        case _:
            print("Please enter a valid difficulty")

def recommend(game):
    print("you migth like :",game)
main()
# Out:
# enter difficult or casual ihad
# multiplayer or singleplayer fajf
# Please enter a valid difficulty

# %%
## lets deacrease the lines of code and more readable

# %%
def main():
    difficulty = input("difficult or casual").capitalize()
    if  difficulty != "Difficult" and difficulty != "Casual":
        print("please enter a valid difficulty")
        return
    players = input("singleplayer or multiplayer").capitalize()
    if players != "Multiplayer" and players != "Singleplayer":
        print("plaese enter valid number of players")
        return
    if difficulty == "Difficult" and players == "Multiplayer":
        recommend("pubg")
    elif difficulty == "Difficult" and players == "Singleplayer":
        recommend("chess")
    elif difficulty == "Casual" and players == "Multiplayer":
        recommend("free fire")
    else :
        recommend("candy crush")
def recommend(game):
    print("you migth like",game)
main()
# Out:
# difficult or casual casual
# singleplayer or multiplayer singleplayer
# you migth like candy crush

# %%
def main():
    difficulty = input("Difficult or casual:")
    if difficulty != DIfficult
