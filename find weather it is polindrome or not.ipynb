# %%
word = input("enter the word:").upper()
reverse = word[::-1]
if reverse == word:
    print("yes it is polindrome")
else:
    print(" no it is not polindrome")
print(reverse)
# Out:
# enter the word: yash
#  no it is not polindrome
# hsaY
