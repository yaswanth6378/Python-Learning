# %% [markdown]
# ## printing a square

# %%
 n = int(input("enter a number"))
for i in range(n):
    for j in range(n):
        print("*",end=" ")
    print()
# Out:
# enter a number 5
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %% [markdown]
# ## prnting rigth angle triangle

# %%
n = int(input("enter a number:"))
for i in range(n):
    for j in range(i+1):
        print("*",end=' ')
    print()
# Out:
# enter a number: 5
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# ## decreaing tri

# %%
n = int(input("enter a number"))
for i in range (n):
    for j in range(i,n):
        print("*",end=" ")
    print()
# Out:
# enter a number 5
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = int(input("enter a number"))
for i in range (n):
    for j in range(i,n):
        print("  ",end="")
    for j in range(i+1):
        print("* ",end= "")
    print()
# Out:
# enter a number 5
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *

# %%
n = 5
for i in range (n):
    for j in range(n):
        print("  ",end="")
    for j in range(i+1):
        print("* ",end="")
    print()
# Out:
#           *
#           * *
#           * * *
#           * * * *
#           * * * * *

# %%
n = 5
for i in range (n):
    for j in range(i,n):
        print(" ",end="")
    for j in range(i+1):
        print("*",end= "")
    for j in range(i+1):
        print("*",end="")
        
    print()
# Out:
#      **
#     ****
#    ******
#   ********
#  **********

# %%
n = int(input("enter a number"))
for i in range (n):
    for j in range(i):
        print(" ",end="")
    for j in range(i,n):
        print("*",end= "")
    print()
# Out:
# enter a number 5
# *****
#  ****
#   ***
#    **
#     *

# %%
n = 5
for i in range (n):
    for j in range(n):
        print("  ",end="")
    for j in range(i,n):
        print("*",end="")
    print()
# Out:
#           *****
#           ****
#           ***
#           **
#           *

# %%
n = int(input("enter a number"))
for i in range (n):
    for j in range(i):
        print(" ",end="")
    for j in range(i,n):
        print("*",end= "")
    for j in range(i,n):
        print("*",end="")
    
    print()
# Out:
# enter a number 5
# **********
#  ********
#   ******
#    ****
#     **

# %%
n = 5
for i in range (n):
    for j in range(i,n):
        print(" ",end="")
    for j in range(i+1):
        print("*",end= "")
    for j in range(i):
        print("*",end="")
    print()
# Out:
#      *
#     ***
#    *****
#   *******
#  *********

# %%
n = int(input("enter a number"))
for i in range (n):
    for j in range(i):
        print(" ",end="")
    for j in range(i,n-1):
        print("*",end= "")
    for j in range(i,n):
        print("*",end="")
    
    print()
# Out:
# enter a number 5
# *********
#  *******
#   *****
#    ***
#     *

# %%
n = 5
for i in range (n):
    for j in range(i,n-1):
        print(" ",end="")
    for j in range(i+1):
        print("*",end= "")
    for j in range(i):
        print("*",end="")       
    print()
for i in range (n):
    for j in range(i):
        print(" ",end="")
    for j in range(i,n-1):
        print("*",end= "")
    for j in range(i,n):
        print("*",end="")
    
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********
# *********
#  *******
#   *****
#    ***
#     *
