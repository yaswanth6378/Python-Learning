# %%
name = 'YASWANTH'
age = 21
heigth = 5.10
is_student = True

# %%
print (name,age,heigth,is_student)
# Out:
# YASWANTH 21 5.1 True

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(heigth))
# Out:
# <class 'float'>

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %%
a,b,c = 5, 10 ,15

# %%
print(a,b,c)
# Out:
# 5 10 15

# %%
num_str = '42'

# %%
print(num_str)
# Out:
# 42

# %%
num_float = float(num_str)

# %%
print(num_float)
# Out:
# 42.0

# %% [markdown]
# ## Input and Output

# %%
print("hello","world","from","python")
# Out:
# hello world from python

# %%
name = input ("Enter your name")
print(name)
# Out:
# Enter your name reddy
# reddy

# %%
a = int (input ("Enter a number"))
print(a * 2)
# Out:
# Enter a number 32
# 64

# %%
name = "Reddy"
marks  = 87.5

# %%
print(f"{name} has  scored {marks} out  of 100" )
# Out:
# Reddy has  scored 87.5 out  of 100

# %%
print(f"Percentage:{marks:1f}%")
# Out:
# Percentage:87.500000%

# %% [markdown]
# ##  operators

# %%
a,b = 10,3

# %%
print(a+b,a-b,a*b)
# Out:
# 13 7 30

# %%
a,b = 10,3

# %%
print(a/b) # divison
# Out:
# 3.3333333333333335

# %%
print(a//b) #
# Out:
# 3

# %%
print(type(a//b)) #
# Out:
# <class 'int'>

# %%
print(a % b) #reminder or modulo operator
# Out:
# 1

# %%
print(a**b) #exponent
# Out:
# 1000

# %%
price = 250
quantity = 4
tax = 0.18
total = price * quantity * (1+tax)

# %%
print(total)
# Out:
# 1180.0

# %% [markdown]
# ## comparison

# %%
print(10 > 5)
print(10 == 5)
print(10 != 5)
# Out:
# True
# False
# True

# %%
marks = 75
print (50 <= marks <=  1000)
# Out:
# True

# %% [markdown]
# ## LOGICAL

# %%
x,y = True,False
print(x and y)
print(x or y)
print(not x)
# Out:
# False
# True
# False

# %%
age = 22
has_id = True
print(age >= 18 and has_id)
# Out:
# True

# %%
income = 50000

# %%
credit_score = 720
eligible = (income> 30000 and credit_score >= 700)
print(eligible)
# Out:
# True

# %% [markdown]
# ### lists

# %%
numbers = [10,20,30,40]
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
print(numbers[0])
# Out:
# 10

# %%
print(numbers[0:4] )
# Out:
# [10, 20, 30, 40]

# %%
print(numbers[1])
# Out:
# 20

# %%
print(numbers[2])
# Out:
# 30

# %% [markdown]
# ## modify,append , remove lists

# %%
fruits = ["apple","banana","mango"]
print(fruits[1])
# Out:
# banana

# %%
fruits.append("orange") # ADD

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
fruits.remove("apple")  # remove

# %%
print(fruits)
# Out:
# ['banana', 'mango', 'orange']

# %%
nums = [1,4,5,6,8]

# %%
print(len(nums))
print(sum(nums))
print(max(nums),min(nums))
# Out:
# 5
# 24
# 8 1

# %%
nums = [2,10,5,4,1,3]
nums.sort()

# %%
print(nums)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
nums = [10,20,30,40,50]
print(nums[1:4])
# Out:
# [20, 30, 40]

# %%
print(nums[:4])
# Out:
# [10, 20, 30, 40]

# %%
print(nums[::])
# Out:
# [10, 20, 30, 40, 50]

# %%
print(nums[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
print(nums)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(nums[:-4])
# Out:
# [10]

# %%
print(nums[1:5:2])
# Out:
# [20, 40]

# %% [markdown]
# ## LOOPS

# %% [markdown]
# ## FOR LOOP

# %%
for i in range (5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (2,11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# marks = [70,80,90]
# for marks in marks:
#     print(marks)

# %% [markdown]
# ## while loop

# %%
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n = 0 
while True :
    if n == 3:
        break
        print("n = ", n)
        n += 1

# %% [markdown]
# ## conditional statement

# %%
age  = 18
if age >= 18:
    print("adult")

# %%
age = 15
if  age >= 18:
    print("adult")
else :
    print("minor")

# %% [markdown]
# ## if - elif(grading)

# %%
marks = int(input("marks :"))
if marks >= 90:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("B")
else:
    print("fail")
# Out:
# marks : 52
# fail

# %%
##define a function with parametersand return

# %%
def add(a,b):
    return a+b

# %%
add (10,20)
# Out:
# 30

# %%
def stats(nums):
    return min(nums),max(nums),sum(nums)/len(nums)

# %%
low,high,avg = stats([10,20,30,40])

# %%
print(low,high,avg)
# Out:
# 10 40 25.0
