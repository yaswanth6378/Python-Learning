# %%
def main():
    names = ["shravya","pallavi","madhav","lachi reddy"]
    for name in names:
        print(write_letter(name,"yaswanth"))
def write_letter(receiver,sender):
    return f"""
    =============================
    TO,
    {receiver} garu,
    april 29 ma anna pelli kaaavuna andaru vicheysi ma anna
    vadhinalanu asiravadhinchu pardhana
    yours lovingly

    {sender}
    ==============================
    """
main()
# Out:
# ...
#     TO,
#     shravya garu,
#     april 29 ma anna pelli kaaavuna andaru vicheysi ma anna
#     vadhinalanu asiravadhinchu pardhana
#     yours lovingly
#
#     yaswanth
# ...
#
#
# ...
#     TO,
#     pallavi garu,
#     april 29 ma anna pelli kaaavuna andaru vicheysi ma anna
#     vadhinalanu asiravadhinchu pardhana
#     yours lovingly
#
#     yaswanth
# ...
#
#
# ...
#     TO,
#     madhav garu,
#     april 29 ma anna pelli kaaavuna andaru vicheysi ma anna
#     vadhinalanu asiravadhinchu pardhana
#     yours lovingly
#
#     yaswanth
# ...
#
#
# ...
#     TO,
#     lachi reddy garu,
#     april 29 ma anna pelli kaaavuna andaru vicheysi ma anna
#     vadhinalanu asiravadhinchu pardhana
#     yours lovingly
#
#     yaswanth
# ...
